# %% [markdown]
# # WeatherPy

# %%
#!pip install requests
#!pip install gmaps
#!pip install citipy
#!pip3 install -U matplotlib

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#output csv file 
output_data_file = "output_data/cities.csv"

#range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

np.random.seed(42)
#weather_api_key

# %% [markdown]
# # Generate Cities List

# %%
#list for holding lat_lngs and cities
lat_lngs = []
cities = []

#creating a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #if the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#showing output
len(cities)
# Out:
# 597

# %% [markdown]
# # Perform API Calls

# %%
#getting url
url = 'http://api.openweathermap.org/data/2.5/weather?'

#api key from api key file
api_key = '6a99cfd9156c43b9a85ce9fab62c3b63'

#setting units
units = 'imperial'
finalurl=f'{url}appid={api_key}&units={units}&q='
response = requests.get(finalurl+'Boston').json()

#print results
print (response)
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 36.93, 'feels_like': 30.6, 'temp_min': 35.01, 'temp_max': 39, 'pressure': 1008, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 160}, 'clouds': {'all': 90}, 'dt': 1612541648, 'sys': {'type': 1, 'id': 3486, 'country': 'US', 'sunrise': 1612525995, 'sunset': 1612562598}, 'timezone': -18000, 'id': 4930956, 'name': 'Boston', 'cod': 200}

# %%
#url
url = 'http://api.openweathermap.org/data/2.5/weather?'

#api key from api key file
api_key = '6a99cfd9156c43b9a85ce9fab62c3b63'
units = 'imperial'
finalurl=f'{url}appid={api_key}&units={units}&q='

#Lists to call data
name = []
lat = []
lng = []
max_temp = []
cloudiness = []
humidity = []
wind_speed = []
country = []
date = []
record=0

#print results
print(f'Beginning Data Retrevial')
print(f'------------------------')

#setting up for loop though cities
for city in cities:
    #url response data in json format
    response = requests.get(finalurl+city).json()
  
    
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_record = response['name']
        
        #printint results
        print(f'Processing Record {record} of {record} | {city_record}')
        record = record+1
    except:
        print('City not found.Skippin....')
        pass

#printing results
print(f'-----------------------')
print(f'Data Retreival Complete')
# Out:
# Beginning Data Retrevial
# ------------------------
# Processing Record 0 of 0 | Henties Bay
# City not found.Skippin....
# Processing Record 1 of 1 | Bethel
# Processing Record 2 of 2 | Saint-François
# Processing Record 3 of 3 | Ushuaia
# Processing Record 4 of 4 | Mar del Plata
# Processing Record 5 of 5 | Kruisfontein
# Processing Record 6 of 6 | Brønnøysund
# City not found.Skippin....
# Processing Record 7 of 7 | Yumen
# Processing Record 8 of 8 | Albany
# Processing Record 9 of 9 | Dikson
# Processing Record 10 of 10 | Ossora
# Processing Record 11 of 11 | Vaini
# Processing Record 12 of 12 | Castro
# City not found.Skippin....
# Processing Record 13 of 13 | Vanimo
# Processing Record 14 of 14 | San Cristobal
# Processing Record 15 of 15 | Ulladulla
# Processing Record 16 of 16 | ‘Ewa Beach
# Processing Record 17 of 17 | Bluff
# Processing Record 18 of 18 | Departamento de Maldonado
# Processing Record 19 of 19 | Mataura
# Processing Record 20 of 20 | Jamestown
# Processing Record 21 of 21 | Geraldton
# Processing Record 22 of 22 | Punta Arenas
# Processing Record 23 of 23 | Mitú
# Processing Record 24 of 24 | Turan
# Processing Record 25 of 25 | Bredasdorp
# City not found.Skippin....
# Processing Record 26 of 26 | Port Alfred
# Processing Record 27 of 27 | Busselton
# Processing Record 28 of 28 | Qaanaaq
# Processing Record 29 of 29 | Sitka
# Processing Record 30 of 30 | Rikitea
# Processing Record 31 of 31 | Yuma
# Processing Record 32 of 32 | Luanda
# Processing Record 33 of 33 | Saint-Philippe
# Processing Record 34 of 34 | Atuona
# Processing Record 35 of 35 | Te Anau
# Processing Record 36 of 36 | Marrakesh
# Processing Record 37 of 37 | Mbaïki
# Processing Record 38 of 38 | Makakilo City
# Processing Record 39 of 39 | East London
# Processing Record 40 of 40 | Cherskiy
# Processing Record 41 of 41 | Lyman
# Processing Record 42 of 42 | Saskylakh
# City not found.Skippin....
# City not found.Skippin....
# Processing Record 43 of 43 | Yellowknife
# Processing Record 44 of 44 | Chui
# Processing Record 45 of 45 | New Norfolk
# Processing Record 46 of 46 | Broken Hill
# Processing Record 47 of 47 | Ribas do Rio Pardo
# Processing Record 48 of 48 | Ancud
# Processing Record 49 of 49 | Vanavara
# Processing Record 50 of 50 | Coquimbo
# Processing Record 51 of 51 | São Filipe
# Processing Record 52 of 52 | Saint Paul Harbor
# Processing Record 53 of 53 | Yurkivka
# City not found.Skippin....
# Processing Record 54 of 54 | Guymon
# Processing Record 55 of 55 | Inhambane
# Processing Record 56 of 56 | Thompson
# Processing Record 57 of 57 | Ponta do Sol
# Processing Record 58 of 58 | Richards Bay
# Processing Record 59 of 59 | Hermanus
# Processing Record 60 of 60 | Russell
# Processing Record 61 of 61 | Angren
# Processing Record 62 of 62 | Hithadhoo
# Processing Record 63 of 63 | Nikolskoye
# Processing Record 64 of 64 | Port Hardy
# Processing Record 65 of 65 | Hilo
# Processing Record 66 of 66 | Shar
# Processing Record 67 of 67 | Goma
# Processing Record 68 of 68 | Pizarro
# Processing Record 69 of 69 | Faanui
# Processing Record 70 of 70 | Hobart
# Processing Record 71 of 71 | Road Town
# Processing Record 72 of 72 | Lebu
# Processing Record 73 of 73 | Amapá
# Processing Record 74 of 74 | Barrow
# Processing Record 75 of 75 | Cape Town
# Processing Record 76 of 76 | Darhan
# Processing Record 77 of 77 | Victor Harbor
# City not found.Skippin....
# Processing Record 78 of 78 | Havre-St-Pierre
# Processing Record 79 of 79 | The Valley
# Processing Record 80 of 80 | Verkhnyaya Inta
# Processing Record 81 of 81 | Beringovskiy
# Processing Record 82 of 82 | Skjervøy
# Processing Record 83 of 83 | Kalmunai
# Processing Record 84 of 84 | Westport
# Processing Record 85 of 85 | Oudtshoorn
# Processing Record 86 of 86 | Grand Gaube
# Processing Record 87 of 87 | La Ronge
# Processing Record 88 of 88 | Terråk
# Processing Record 89 of 89 | Bonthe
# Processing Record 90 of 90 | Bengkulu
# Processing Record 91 of 91 | Necochea
# Processing Record 92 of 92 | Chokurdakh
# Processing Record 93 of 93 | Itarema
# Processing Record 94 of 94 | Pacifica
# Processing Record 95 of 95 | Isangel
# Processing Record 96 of 96 | Esperance
# Processing Record 97 of 97 | Port-Gentil
# City not found.Skippin....
# Processing Record 98 of 98 | Lompoc
# Processing Record 99 of 99 | Bontang
# Processing Record 100 of 100 | Mahébourg
# Processing Record 101 of 101 | Lavrentiya
# Processing Record 102 of 102 | Coyhaique
# Processing Record 103 of 103 | Breves
# Processing Record 104 of 104 | Tuatapere
# Processing Record 105 of 105 | Ajdabiya
# Processing Record 106 of 106 | St-Jean-Port-Joli
# Processing Record 107 of 107 | Vila Franca do Campo
# Processing Record 108 of 108 | Kiryat Gat
# Processing Record 109 of 109 | Katsuura
# Processing Record 110 of 110 | Konongo
# Processing Record 111 of 111 | Kaitangata
# Processing Record 112 of 112 | Tommot
# Processing Record 113 of 113 | Wanning
# Processing Record 114 of 114 | Ribeira Grande
# Processing Record 115 of 115 | Sorong
# Processing Record 116 of 116 | Rongcheng
# Processing Record 117 of 117 | Kahului
# Processing Record 118 of 118 | Caravelas
# Processing Record 119 of 119 | Norman Wells
# Processing Record 120 of 120 | São Luiz Gonzaga
# City not found.Skippin....
# Processing Record 121 of 121 | Udachny
# Processing Record 122 of 122 | Naze
# Processing Record 123 of 123 | Ola
# Processing Record 124 of 124 | Ferkessédougou
# Processing Record 125 of 125 | Yabēlo
# Processing Record 126 of 126 | Roald
# Processing Record 127 of 127 | Tasiilaq
# Processing Record 128 of 128 | Laguna
# Processing Record 129 of 129 | Avera
# Processing Record 130 of 130 | Kapaa
# Processing Record 131 of 131 | Tuktoyaktuk
# Processing Record 132 of 132 | Bilibino
# Processing Record 133 of 133 | Krapkowice
# Processing Record 134 of 134 | Butaritari
# Processing Record 135 of 135 | Santa Maria
# City not found.Skippin....
# Processing Record 136 of 136 | Cabo San Lucas
# Processing Record 137 of 137 | Panzhihua
# Processing Record 138 of 138 | Waipawa
# Processing Record 139 of 139 | Avarua
# City not found.Skippin....
# Processing Record 140 of 140 | Souillac
# Processing Record 141 of 141 | Makkah al Mukarramah
# Processing Record 142 of 142 | Hauterive
# City not found.Skippin....
# Processing Record 143 of 143 | Gouré
# Processing Record 144 of 144 | Touros
# Processing Record 145 of 145 | Oga
# Processing Record 146 of 146 | Codrington
# Processing Record 147 of 147 | Khatanga
# Processing Record 148 of 148 | Klaksvík
# City not found.Skippin....
# Processing Record 149 of 149 | Puerto Ayora
# Processing Record 150 of 150 | Provideniya
# Processing Record 151 of 151 | Phan Thiet
# Processing Record 152 of 152 | Pevek
# City not found.Skippin....
# Processing Record 153 of 153 | Nouadhibou
# Processing Record 154 of 154 | Tiksi
# Processing Record 155 of 155 | Jacqueville
# Processing Record 156 of 156 | Halifax
# Processing Record 157 of 157 | Korla
# Processing Record 158 of 158 | Lagos
# Processing Record 159 of 159 | Ilhabela
# Processing Record 160 of 160 | Vidim
# City not found.Skippin....
# Processing Record 161 of 161 | Kluang
# Processing Record 162 of 162 | São Gabriel da Cachoeira
# Processing Record 163 of 163 | Sergeevka
# Processing Record 164 of 164 | Los Llanos de Aridane
# Processing Record 165 of 165 | Paris
# Processing Record 166 of 166 | Urusha
# Processing Record 167 of 167 | Nome
# Processing Record 168 of 168 | Salalah
# Processing Record 169 of 169 | Hong Kong
# Processing Record 170 of 170 | Ginir
# Processing Record 171 of 171 | Abalak
# Processing Record 172 of 172 | Varhaug
# Processing Record 173 of 173 | Bambous Virieux
# City not found.Skippin....
# Processing Record 174 of 174 | Iracoubo
# Processing Record 175 of 175 | Cockburn Town
# Processing Record 176 of 176 | Saint-Pierre
# Processing Record 177 of 177 | Hinton
# City not found.Skippin....
# Processing Record 178 of 178 | Sterling
# Processing Record 179 of 179 | Severo-Kuril'sk
# Processing Record 180 of 180 | Camaná
# Processing Record 181 of 181 | Ixtapa
# Processing Record 182 of 182 | Fortuna
# Processing Record 183 of 183 | Sakakah
# Processing Record 184 of 184 | Follonica
# Processing Record 185 of 185 | Srandakan
# Processing Record 186 of 186 | Vao
# Processing Record 187 of 187 | Osypenko
# Processing Record 188 of 188 | Mayo
# Processing Record 189 of 189 | Saint George
# Processing Record 190 of 190 | Kokopo
# Processing Record 191 of 191 | Carutapera
# Processing Record 192 of 192 | George Town
# Processing Record 193 of 193 | Cidreira
# Processing Record 194 of 194 | Pemba
# Processing Record 195 of 195 | Poum
# Processing Record 196 of 196 | Paraíso
# Processing Record 197 of 197 | Mount Isa
# Processing Record 198 of 198 | Abu Dhabi
# Processing Record 199 of 199 | Valle del Guamuez
# Processing Record 200 of 200 | Mirny
# Processing Record 201 of 201 | Houma
# City not found.Skippin....
# Processing Record 202 of 202 | Kattivākkam
# City not found.Skippin....
# Processing Record 203 of 203 | Sharjah city
# Processing Record 204 of 204 | Moundou
# Processing Record 205 of 205 | Yangi Marg`ilon
# Processing Record 206 of 206 | Huilong
# Processing Record 207 of 207 | Saldanha
# Processing Record 208 of 208 | Suoyarvi
# Processing Record 209 of 209 | Chapais
# Processing Record 210 of 210 | Plettenberg Bay
# Processing Record 211 of 211 | Tottori-shi
# Processing Record 212 of 212 | Abu Samrah
# Processing Record 213 of 213 | Forsytheganj
# Processing Record 214 of 214 | Ashland
# Processing Record 215 of 215 | Dingle
# Processing Record 216 of 216 | Yining
# Processing Record 217 of 217 | Belmonte
# Processing Record 218 of 218 | Carnarvon
# Processing Record 219 of 219 | Gravelbourg
# Processing Record 220 of 220 | Warmbad
# Processing Record 221 of 221 | Lukovetskiy
# Processing Record 222 of 222 | Torbay
# Processing Record 223 of 223 | Khovd
# Processing Record 224 of 224 | Meulaboh
# Processing Record 225 of 225 | Pouébo
# Processing Record 226 of 226 | Upernavik
# Processing Record 227 of 227 | Los Andes
# Processing Record 228 of 228 | Leningradskiy
# Processing Record 229 of 229 | Sinnamary
# Processing Record 230 of 230 | Lagoa
# Processing Record 231 of 231 | Makīnsk
# Processing Record 232 of 232 | Gurupá
# Processing Record 233 of 233 | Chinsali
# Processing Record 234 of 234 | Port Elizabeth
# Processing Record 235 of 235 | Ineu
# Processing Record 236 of 236 | Faya
# City not found.Skippin....
# Processing Record 237 of 237 | Chara
# Processing Record 238 of 238 | La Unión
# Processing Record 239 of 239 | Narsaq
# City not found.Skippin....
# Processing Record 240 of 240 | Shestakovo
# Processing Record 241 of 241 | Newport
# City not found.Skippin....
# Processing Record 242 of 242 | Barra de Tecoanapa
# Processing Record 243 of 243 | Lichinga
# City not found.Skippin....
# Processing Record 244 of 244 | Namatanai
# Processing Record 245 of 245 | Cabedelo
# Processing Record 246 of 246 | Tongliao
# Processing Record 247 of 247 | Cayenne
# Processing Record 248 of 248 | Longyearbyen
# Processing Record 249 of 249 | Giyani
# Processing Record 250 of 250 | Qasigiannguit
# Processing Record 251 of 251 | Rawson
# Processing Record 252 of 252 | Sørland
# Processing Record 253 of 253 | Aguazul
# City not found.Skippin....
# Processing Record 254 of 254 | Constitución
# Processing Record 255 of 255 | Tongchuanshi
# Processing Record 256 of 256 | Taoudenni
# Processing Record 257 of 257 | Guerrero Negro
# Processing Record 258 of 258 | Margate
# Processing Record 259 of 259 | Padang
# Processing Record 260 of 260 | Manchester
# Processing Record 261 of 261 | Santa Cruz de la Sierra
# Processing Record 262 of 262 | Griffith
# Processing Record 263 of 263 | Sioux Lookout
# Processing Record 264 of 264 | Martinez
# Processing Record 265 of 265 | Kodinsk
# Processing Record 266 of 266 | Avila
# Processing Record 267 of 267 | Dourados
# Processing Record 268 of 268 | Okha
# Processing Record 269 of 269 | Ghanzi
# Processing Record 270 of 270 | Olafsvik
# Processing Record 271 of 271 | Talara
# Processing Record 272 of 272 | Riwaka
# Processing Record 273 of 273 | Kozhva
# Processing Record 274 of 274 | Meadow Lake
# Processing Record 275 of 275 | Lenina
# Processing Record 276 of 276 | Haines Junction
# Processing Record 277 of 277 | Itoman
# Processing Record 278 of 278 | Talwandi Bhai
# Processing Record 279 of 279 | Nola
# Processing Record 280 of 280 | Zhigansk
# Processing Record 281 of 281 | Karaton
# Processing Record 282 of 282 | Bilma
# Processing Record 283 of 283 | Kosum Phisai
# Processing Record 284 of 284 | Pimentel
# Processing Record 285 of 285 | Presidencia Roque Sáenz Peña
# Processing Record 286 of 286 | Leverkusen
# Processing Record 287 of 287 | Khandyga
# City not found.Skippin....
# City not found.Skippin....
# Processing Record 288 of 288 | Dubbo
# Processing Record 289 of 289 | Marzuq
# Processing Record 290 of 290 | Lüderitz
# Processing Record 291 of 291 | Clyde River
# Processing Record 292 of 292 | Metro
# Processing Record 293 of 293 | Marsá Maţrūḩ
# Processing Record 294 of 294 | Pauini
# Processing Record 295 of 295 | Mount Gambier
# Processing Record 296 of 296 | Emerald
# Processing Record 297 of 297 | Muisne
# Processing Record 298 of 298 | Shellbrook
# Processing Record 299 of 299 | Usinsk
# Processing Record 300 of 300 | Terney
# Processing Record 301 of 301 | Ambilobe
# Processing Record 302 of 302 | Redmond
# Processing Record 303 of 303 | Arraial do Cabo
# Processing Record 304 of 304 | West Sacramento
# Processing Record 305 of 305 | Lisala
# Processing Record 306 of 306 | Bali
# Processing Record 307 of 307 | Merauke
# Processing Record 308 of 308 | Yulara
# Processing Record 309 of 309 | La Rioja
# Processing Record 310 of 310 | Ndioum
# Processing Record 311 of 311 | Worcester
# Processing Record 312 of 312 | Kushtagi
# Processing Record 313 of 313 | Chifeng
# Processing Record 314 of 314 | San Alberto
# Processing Record 315 of 315 | Adeje
# Processing Record 316 of 316 | Port Blair
# Processing Record 317 of 317 | Saint-Joseph
# Processing Record 318 of 318 | Bahía Blanca
# Processing Record 319 of 319 | Pundaguitan
# Processing Record 320 of 320 | Toamasina
# Processing Record 321 of 321 | Iqaluit
# Processing Record 322 of 322 | Hamilton
# Processing Record 323 of 323 | Kavieng
# City not found.Skippin....
# Processing Record 324 of 324 | Bulgan
# Processing Record 325 of 325 | Cairns
# Processing Record 326 of 326 | San Policarpo
# Processing Record 327 of 327 | Urbano Santos
# Processing Record 328 of 328 | São João da Barra
# Processing Record 329 of 329 | Zeya
# Processing Record 330 of 330 | Hasaki
# Processing Record 331 of 331 | Ulaangom
# City not found.Skippin....
# Processing Record 332 of 332 | Luganville
# Processing Record 333 of 333 | Austin
# City not found.Skippin....
# Processing Record 334 of 334 | Khotynets
# Processing Record 335 of 335 | Sarangani
# Processing Record 336 of 336 | Kirovsk
# Processing Record 337 of 337 | Athabasca
# Processing Record 338 of 338 | Pisco
# Processing Record 339 of 339 | Cikupa
# Processing Record 340 of 340 | Sfântu Gheorghe
# City not found.Skippin....
# Processing Record 341 of 341 | Port Lincoln
# City not found.Skippin....
# City not found.Skippin....
# Processing Record 342 of 342 | Sur
# Processing Record 343 of 343 | Northam
# Processing Record 344 of 344 | Slonim
# Processing Record 345 of 345 | Arlit
# Processing Record 346 of 346 | Vestmannaeyjar
# Processing Record 347 of 347 | Burnie
# Processing Record 348 of 348 | Aden
# Processing Record 349 of 349 | Bereznehuvate
# Processing Record 350 of 350 | Staryy Nadym
# Processing Record 351 of 351 | Nanortalik
# Processing Record 352 of 352 | Arrondissement de Saint-Denis
# City not found.Skippin....
# Processing Record 353 of 353 | Calvià
# Processing Record 354 of 354 | Pushkino
# Processing Record 355 of 355 | Corinth
# Processing Record 356 of 356 | San Jose
# Processing Record 357 of 357 | Bull Savanna
# Processing Record 358 of 358 | Egvekinot
# Processing Record 359 of 359 | Dogondoutchi
# Processing Record 360 of 360 | Jérémie
# Processing Record 361 of 361 | Samarai
# Processing Record 362 of 362 | Ostrovnoy
# City not found.Skippin....
# Processing Record 363 of 363 | Anadyr
# Processing Record 364 of 364 | Iralaya
# Processing Record 365 of 365 | Ekhabi
# Processing Record 366 of 366 | Patacamaya
# Processing Record 367 of 367 | Kudat
# Processing Record 368 of 368 | Derbent
# City not found.Skippin....
# Processing Record 369 of 369 | Santana
# Processing Record 370 of 370 | Iguape
# Processing Record 371 of 371 | ‘Āhuimanu
# Processing Record 372 of 372 | Mayuge
# City not found.Skippin....
# Processing Record 373 of 373 | Damaturu
# Processing Record 374 of 374 | Olinda
# Processing Record 375 of 375 | El Calvario
# Processing Record 376 of 376 | Sinazongwe
# Processing Record 377 of 377 | Sisimiut
# Processing Record 378 of 378 | Khipro
# Processing Record 379 of 379 | Maragogi
# Processing Record 380 of 380 | Nantucket
# Processing Record 381 of 381 | Yibin
# Processing Record 382 of 382 | Kaseda-shirakame
# Processing Record 383 of 383 | Sept-Îles
# Processing Record 384 of 384 | Hay River
# Processing Record 385 of 385 | Grindavik
# Processing Record 386 of 386 | Shimoda
# Processing Record 387 of 387 | Rincon
# Processing Record 388 of 388 | Qaqortoq
# Processing Record 389 of 389 | Verāval
# City not found.Skippin....
# Processing Record 390 of 390 | Bétérou
# Processing Record 391 of 391 | Lata
# Processing Record 392 of 392 | Talnakh
# Processing Record 393 of 393 | Chincha Alta
# Processing Record 394 of 394 | Portland
# Processing Record 395 of 395 | Suntar
# Processing Record 396 of 396 | Toro
# City not found.Skippin....
# Processing Record 397 of 397 | Lakhīmpur
# Processing Record 398 of 398 | Khani
# Processing Record 399 of 399 | George Town
# Processing Record 400 of 400 | Kabwe
# Processing Record 401 of 401 | Goderich
# Processing Record 402 of 402 | Airai
# Processing Record 403 of 403 | Gweta
# Processing Record 404 of 404 | Kangaba
# Processing Record 405 of 405 | Kinshasa
# Processing Record 406 of 406 | Seguin
# Processing Record 407 of 407 | Nemuro
# Processing Record 408 of 408 | Kwang Binh
# Processing Record 409 of 409 | Knyaze-Volkonskoye
# Processing Record 410 of 410 | Peniche
# City not found.Skippin....
# City not found.Skippin....
# City not found.Skippin....
# Processing Record 411 of 411 | Matagami
# Processing Record 412 of 412 | South Valley
# Processing Record 413 of 413 | Mehamn
# Processing Record 414 of 414 | São José da Coroa Grande
# Processing Record 415 of 415 | Sabang
# Processing Record 416 of 416 | Rovaniemi
# Processing Record 417 of 417 | Fukuechō
# Processing Record 418 of 418 | Naghadeh
# City not found.Skippin....
# City not found.Skippin....
# Processing Record 419 of 419 | Ayabaca
# City not found.Skippin....
# Processing Record 420 of 420 | Catuday
# Processing Record 421 of 421 | Yinzhu
# Processing Record 422 of 422 | Bandarbeyla
# Processing Record 423 of 423 | Toora-Khem
# Processing Record 424 of 424 | College
# Processing Record 425 of 425 | Klyuchi
# Processing Record 426 of 426 | Noumea
# Processing Record 427 of 427 | Furtwangen im Schwarzwald
# Processing Record 428 of 428 | Punta de Bombón
# Processing Record 429 of 429 | Tessalit
# Processing Record 430 of 430 | Aykhal
# Processing Record 431 of 431 | Conde
# Processing Record 432 of 432 | Cohoes
# Processing Record 433 of 433 | Sambava
# Processing Record 434 of 434 | Sabha
# Processing Record 435 of 435 | Dalvik
# Processing Record 436 of 436 | Berlevåg
# Processing Record 437 of 437 | Micheweni
# Processing Record 438 of 438 | Hongjiang
# Processing Record 439 of 439 | Luba
# Processing Record 440 of 440 | Greater Sudbury
# Processing Record 441 of 441 | Gilgit
# Processing Record 442 of 442 | Arroyo de la Encomienda
# Processing Record 443 of 443 | Arman'
# Processing Record 444 of 444 | Quatre Cocos
# Processing Record 445 of 445 | Ucar
# Processing Record 446 of 446 | Chamba
# Processing Record 447 of 447 | Buala
# Processing Record 448 of 448 | Ratnagiri
# Processing Record 449 of 449 | Yaan
# Processing Record 450 of 450 | Bereda
# Processing Record 451 of 451 | Adrar
# Processing Record 452 of 452 | Hofn
# Processing Record 453 of 453 | La Santisima Trinidad
# Processing Record 454 of 454 | Kyaukse
# Processing Record 455 of 455 | Stornoway
# City not found.Skippin....
# Processing Record 456 of 456 | Juneau
# Processing Record 457 of 457 | General Roca
# Processing Record 458 of 458 | Talen
# Processing Record 459 of 459 | Shingū
# Processing Record 460 of 460 | Mutatá
# Processing Record 461 of 461 | Bonavista
# Processing Record 462 of 462 | Ikare
# Processing Record 463 of 463 | Ilulissat
# Processing Record 464 of 464 | Wad Medani
# Processing Record 465 of 465 | Atar
# Processing Record 466 of 466 | Sistranda
# Processing Record 467 of 467 | Frutigen
# City not found.Skippin....
# Processing Record 468 of 468 | Labuhan
# Processing Record 469 of 469 | Soyo
# Processing Record 470 of 470 | Hirara
# Processing Record 471 of 471 | Itacaré
# Processing Record 472 of 472 | Kasangulu
# Processing Record 473 of 473 | Carberry
# Processing Record 474 of 474 | Arrondissement du Havre
# Processing Record 475 of 475 | Zavetnoye
# Processing Record 476 of 476 | Simao
# Processing Record 477 of 477 | Huayucachi
# Processing Record 478 of 478 | Opuwo
# Processing Record 479 of 479 | Kidal
# City not found.Skippin....
# Processing Record 480 of 480 | Khilok
# Processing Record 481 of 481 | Mushie
# Processing Record 482 of 482 | Yatou
# Processing Record 483 of 483 | Kutum
# Processing Record 484 of 484 | Cullman
# Processing Record 485 of 485 | Cedar City
# City not found.Skippin....
# Processing Record 486 of 486 | Kumul
# Processing Record 487 of 487 | Prince George
# Processing Record 488 of 488 | Severnoye
# City not found.Skippin....
# Processing Record 489 of 489 | Kaniama
# Processing Record 490 of 490 | Myitkyina
# Processing Record 491 of 491 | Winneba
# Processing Record 492 of 492 | Leshukonskoye
# Processing Record 493 of 493 | Boundiali
# Processing Record 494 of 494 | Abadan
# Processing Record 495 of 495 | Dunedin
# Processing Record 496 of 496 | Zyryanka
# Processing Record 497 of 497 | Dobrić
# Processing Record 498 of 498 | São Miguel do Araguaia
# Processing Record 499 of 499 | Puerto Madero
# Processing Record 500 of 500 | Raudeberg
# Processing Record 501 of 501 | Aswān
# Processing Record 502 of 502 | Mahon
# Processing Record 503 of 503 | Ust-Nera
# Processing Record 504 of 504 | Vestmanna
# Processing Record 505 of 505 | Acapulco de Juárez
# Processing Record 506 of 506 | Macia
# Processing Record 507 of 507 | Kununurra
# Processing Record 508 of 508 | Sawtell
# Processing Record 509 of 509 | Creil
# Processing Record 510 of 510 | Ruteng
# Processing Record 511 of 511 | Eyl
# Processing Record 512 of 512 | Ust-Maya
# Processing Record 513 of 513 | Lobito
# City not found.Skippin....
# Processing Record 514 of 514 | Oranjestad
# Processing Record 515 of 515 | Puerto Escondido
# Processing Record 516 of 516 | Bell Ville
# City not found.Skippin....
# Processing Record 517 of 517 | Laela
# Processing Record 518 of 518 | Waddān
# Processing Record 519 of 519 | Kumluca
# Processing Record 520 of 520 | Havelock
# Processing Record 521 of 521 | Tazmalt
# Processing Record 522 of 522 | Aras
# Processing Record 523 of 523 | Samarinda
# Processing Record 524 of 524 | Dhāri
# Processing Record 525 of 525 | Novy Urengoy
# Processing Record 526 of 526 | Koundara
# Processing Record 527 of 527 | Yar-Sale
# Processing Record 528 of 528 | Joshīmath
# Processing Record 529 of 529 | Kushikino
# Processing Record 530 of 530 | Dayong
# Processing Record 531 of 531 | Senanga
# Processing Record 532 of 532 | Southampton
# Processing Record 533 of 533 | Altamont
# Processing Record 534 of 534 | Imbituba
# Processing Record 535 of 535 | Yerofey Pavlovich
# Processing Record 536 of 536 | Ruska Poliana
# Processing Record 537 of 537 | Sola
# Processing Record 538 of 538 | Dhidhdhoo
# Processing Record 539 of 539 | Vredendal
# City not found.Skippin....
# Processing Record 540 of 540 | Kushima
# Processing Record 541 of 541 | Eirunepé
# Processing Record 542 of 542 | Tocopilla
# Processing Record 543 of 543 | Verkhoyansk
# -----------------------
# Data Retreival Complete

# %% [markdown]
# # Convert Raw Data to DataFrame

# %%
#setting up dataframe
town_df = pd.DataFrame({'City': name, 'Lat': lat, 'Lng': lng, 'Max Temp': max_temp,
                         'Humidity': humidity, 'Cloudiness': cloudiness, 
                         'Wind Speed': wind_speed, 'Country': country, 'Date': date})

#showing output
town_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Henties Bay -22.1160  14.2845     66.99        86          33
# 1          Bethel  41.3712 -73.4140     36.00        93          90
# 2  Saint-François  46.4154   3.9054     53.01        82           0
# 3         Ushuaia -54.8000 -68.3000     48.20        81          75
# 4   Mar del Plata -38.0023 -57.5575     73.40        60           0
#
#    Wind Speed Country        Date
# 0        1.01      NA  1612541812
# 1        5.75      US  1612541812
# 2        4.61      FR  1612541812
# 3       34.52      AR  1612541678
# 4        8.05      AR  1612541812

# %%
#store csv for use on the second half of the project
town_df.to_csv(r'../output_data/cities.csv', index=False)

# %%
#using describe to show dataframe
stats = town_df.describe()

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.

# %%
humidity = town_df.loc[town_df['Humidity']>100]

#showing ouput
humidity.head()
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#get the indices of cities that have humidity over 100%.
indices = town_df.index[town_df['Humidity'] > 100].tolist()

#printing results
print(indices)
# Out:
# []

# %%
#get the indices of cities that have humidity over 100%.
rows = town_df.index[indices]

#reseting index
town_df.reset_index

#dropping rows
clean_town_data = town_df.drop(rows, inplace=True)

#showint putput
clean_town_data

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_town_data = town_df

#showing output
len(clean_town_data)
# Out:
# 544

# %% [markdown]
# # Plotting the Data

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
#setting date
ts = pd.Timestamp.today().strftime('%m-%d-%Y')
clean_town_data.plot(kind="scatter", x="Lat", y="Max Temp", marker="o", s=40, facecolors="green", edgecolors="black", grid=True, title="City Latitude vs. Max Temperature" + ts)

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Max Temperature (F)')

#save plot to png
plt.savefig("../output_data/Latitude_vs_Max_Temp.png")
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
#setting date
ts = pd.Timestamp.today().strftime('%m-%d-%Y')
clean_town_data.plot(kind="scatter", x="Lat", y="Humidity", marker="o", s=40, facecolors="green", edgecolor="black", grid=True, title="City Latitude vs. Humidity")

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Humidity')

#save plot to png
plt.savefig("../output_data/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
#setting date
ts = pd.Timestamp.today().strftime('%m-%d-%Y')
clean_town_data.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", s=40, facecolor="green", edgecolors="black", grid=True, title="City Latitude vs. Cloudiness" + ts)

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Cloudiness (%)')

#save plot to png
plt.savefig("../output_data/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
#setting date
ts = pd.Timestamp.today().strftime('%m-%d-%Y')
clean_town_data.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", s=40, facecolor="green", edgecolors="black", grid=True, title="City Latitude vs. Wind Speed" + ts)

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('MPH)')

#save plot to png
plt.savefig("../output_data/Latitude_vs_Wind_Speed.png")
plt.show()

# %% [markdown]
# # Linear Regression

# %%
#setting dataframe per hemisphere
north = clean_town_data.loc[clean_town_data['Lat']>0]
south = clean_town_data.loc[clean_town_data['Lat']<0]

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = north['Lat']
y_values = north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_value = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_value,"r-")

#adding line equation to plot
plt.annotate(line_eq,(6,10),fontsize=15,color="green")

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Max Temperature')

#displays r value
print(f'The r-squared is: {rvalue**2}')

#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.7690996339833508

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = south['Lat']
y_values = south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_value = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_value,"r-")

#adding line equation to plot
plt.annotate(line_eq,(-10,60),fontsize=15,color="green")

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Max Temperature')

#displays r value
print(f'The r-squared is: {rvalue**2}')

#save plot as png
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.30360362330530555

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = north['Lat']
y_values = north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_value = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_value,"r-")

#adding line equation to plot
plt.annotate(line_eq,(5,30),fontsize=15,color="green")

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Humidity')

#displays r value
print(f'The r-squared is: {rvalue**2}')

#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.18215147272838414

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = south['Lat']
y_values = south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_ep = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#creating plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,'r-')

#adding line equation to plot
plt.annotate(line_eq,(-30,30), fontsize=15, color='red')

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Humidity')

#displays r value
print(f'The r_squared is: {rvalue**2}')

#save plot as png
plt.savefig('../output_data/Southern Hemisphere - Humidity (%) vs. Latitude linear Regression.png')
plt.show()
# Out:
# The r_squared is: 0.011927906745728563

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = north['Lat']
y_values = north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_ep = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#creating plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,'r-')

#adding line equation to plot
plt.annotate(line_eq,(5,30), fontsize=15, color='red')

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Cloudiness')

#displays r value
print(f'The r_squared is: {rvalue**2}')

#save plot as png
plt.savefig('../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude linear Regression.png')
plt.show()
# Out:
# The r_squared is: 0.05555368466114499

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = south['Lat']
y_values = south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_ep = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#creating plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,'r-')

#adding line equation to plot
plt.annotate(line_eq,(-30,30), fontsize=15, color='red')

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Cloudiness')

#displays r value
print(f'The r_squared is: {rvalue**2}')

#save plot as png
plt.savefig('../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude linear Regression.png')
plt.show()
# Out:
# The r_squared is: 0.015064669118190419

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = north['Lat']
y_values = north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_ep = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#creating plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,'r-')

#adding line equation to plot
plt.annotate(line_eq,(5,30), fontsize=15, color='red')

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Wind Speed')

#displays r value
print(f'The r_squared is: {rvalue**2}')

#save plot as png
plt.savefig('../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude linear Regression.png')
plt.show()
# Out:
# The r_squared is: 0.009290195749440407

# %% [markdown]
# ### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Add the linear regession equation and line to plot 
#axis values
x_values = south['Lat']
y_values = south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_ep = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#creating plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, 'r-')

#adding line equation to plot
plt.annotate(line_ep, (-30,30), fontsize=15, color='red')

#setting x axis title
plt.xlabel('Latitude')

#setting y axis title
plt.ylabel('Wind Speed')

#displays r value
print(f'The r_squared is: {rvalue**2}')

#save plot as png
plt.savefig('../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude linear Regression.png')
plt.show()
# Out:
# The r_squared is: 0.04008685466252249
